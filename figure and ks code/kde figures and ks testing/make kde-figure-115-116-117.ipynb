# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import os
import matplotlib.patches as mpatches

# %%
os.chdir("/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/")

# %%
image0 = plt.imread("115_valence_scaled_0.png")
image1 = plt.imread("116_valence_scaled_0.png")
image2 = plt.imread("117_valence_scaled_0.png")

image3 = plt.imread("115_arousal_scaled_0.png")
image4 = plt.imread("116_arousal_scaled_0.png")
image5 = plt.imread("117_arousal_scaled_0.png")

image6 = plt.imread("115_confidence_scaled_0.png")
image7 = plt.imread("116_confidence_scaled_0.png")
image8 = plt.imread("117_confidence_scaled_0.png")

image9 = plt.imread("115_sympathy_scaled_0.png")
image10 = plt.imread("116_sympathy_scaled_0.png")
image11 = plt.imread("117_sympathy_scaled_0.png")

image12 = plt.imread("115_empathy_scaled_0.png")
image13 = plt.imread("116_empathy_scaled_0.png")
image14 = plt.imread("117_empathy_scaled_0.png")

image= [image0, image1, image2, image3, image4, image5, image6, image7, image8, image9, image10, image11, image12, image13, image14]

#image_title= ["1000", "2000", "3000", "5000", "10000", "15000", "20000", "25000", "30000", "10"]

fig, axes = plt.subplots(5, 3, figsize=(10, 10), layout='compressed', dpi= 500)

red_patch = mpatches.Patch(color='red', label='Republican', linestyle="-")
blue_patch = mpatches.Patch(color='blue', label='Democrat', linestyle="-")
#plt.legend(handles=[red_patch, blue_patch], loc=(1.04, 6.63))

#plt.legend(handles=[red_patch, blue_patch], bbox_to_anchor=(1.04, 1), borderaxespad=0)

idx=0 
for row in [0, 1, 2, 3, 4]:
    for column in [0, 1, 2]:
        ax = axes[row, column]
        #ax.set_title(image_title[idx], y=-0.21) #f"Image ({row}, {column})")
        ax.axis('off')
        ax.imshow(image[idx])
        idx += 1 
        
axes[0, 0].set_title("115th", fontsize = 15)
axes[0, 1].set_title("116th", fontsize = 15)
axes[0, 2].set_title("117th", fontsize = 15)

plt.figtext(.18, .85, 'Valence', rotation = 90, fontsize = 15)
plt.figtext(.18, .66, 'Arousal', rotation = 90, fontsize = 15)
plt.figtext(.18, .45, 'Confidence', rotation = 90, fontsize = 15)
plt.figtext(.18, .26, 'Sympathy', rotation = 90, fontsize = 15)
plt.figtext(.18, .07, 'Empathy', rotation = 90, fontsize = 15)


plt.show()
#plt.savefig("VACES_plots_scaledy_full.png", bbox_inches='tight')

# %%
plt.show()
