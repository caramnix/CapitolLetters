# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %%
df= pd.read_csv("/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/speeches_VAC_116th/speeches_with_valence.csv")

# %%
def get_party(data):
    return(data[0])
df["party"] = df["party_state"].str.split("-").apply(get_party)

# %%
df["party_2"]= np.where(df["party"] == "R", "R", "D")

# %%
print(sum(df["party_2"] =="D")) #2166 D 
print(sum(df["party_2"] =="R")) #1652 R
print(len(df)) #3818
print(sum(df["party_2"] =="R")/len(df))
# Out:
# 2166
# 1652
# 3818
# 0.4326872708224201

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="valence", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Valence")


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 9.444444444444438, 'Valence')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="valence", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Valence", fontsize=17)
plt.ylabel("Density", fontsize=13)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_valence.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="valence", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Valence", fontsize=17)
plt.ylabel("Density", fontsize=13)

plt.ylim(0, .75)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_valence_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="valence", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("", fontsize=13)

plt.ylim(0, .75)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_valence_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
from scipy import stats

ks= stats.ks_2samp(df[df["party_2"] =="D"].valence, df[df["party_2"] =="R"].valence)
ks
# Out:
# KstestResult(statistic=0.12383545840515651, pvalue=5.514528365576761e-13, statistic_location=0.56, statistic_sign=1)

# %%
ks.pvalue <.05
# Out:
# True

# %%
df2= pd.read_csv("/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/speeches_VAC_116th/speeches_with_VAC.csv")


def get_party(data):
    return(data[0])
df2["party"] = df2["party_state"].str.split("-").apply(get_party)

# %%
df2["party_2"]= np.where(df2["party"] == "R", "R", "D")

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="valence", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Valence")


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 9.444444444444438, 'Valence')

# %%
ks= stats.ks_2samp(df2[df2["party_2"] =="D"].valence, df2[df2["party_2"] =="R"].valence)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.12383545840515651, pvalue=5.514528365576761e-13, statistic_location=0.56, statistic_sign=1)
# True

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df2, x="arousal", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Arousal of 116th House One-Minute Speeches by Party")
plt.xlabel("Arousal")
plt.ylim(0, 1.7)

#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# (0.0, 1.7)

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df2, x="arousal", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Arousal", fontsize=17)
plt.ylabel("Density", fontsize=13)


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_arousal.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df2, x="arousal", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Arousal", fontsize=17)
plt.ylabel("Density", fontsize=13)


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_arousal_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df2, x="arousal", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("", fontsize=13)


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_arousal_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
ks= stats.ks_2samp(df2[df2["party_2"] =="D"].arousal, df2[df2["party_2"] =="R"].arousal)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.16231591467518036, pvalue=5.048411283319375e-22, statistic_location=0.57, statistic_sign=-1)
# True

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df2, x="confidence", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Confidence of 116th House One-Minute Speeches by Party")
plt.xlabel("Confidence")

#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# (0.0, 2.5)

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df2, x="confidence", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Confidence", fontsize=17)
plt.ylabel("Density", fontsize=13)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_confidence.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df2, x="confidence", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Confidence", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 2.7)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_confidence_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df2, x="confidence", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("", fontsize=13)
plt.ylim(0, 2.7)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_confidence_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
ks= stats.ks_2samp(df2[df2["party_2"] =="D"].confidence, df2[df2["party_2"] =="R"].confidence)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.03893039914684123, pvalue=0.11286592676353029, statistic_location=0.6, statistic_sign=-1)
# False

# %%
df3= pd.read_csv("/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/speeches_VAC_116th/speeches_116_with_ES_v2.csv")

def get_party(data):
    return(data[0])
df3["party"] = df3["party_state"].str.split("-").apply(get_party)

df3["party_2"]= np.where(df3["party"] == "R", "R", "D")

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df3, x="empathy", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Empathy of 116th House One-Minute Speeches by Party")
plt.xlabel("Empathy")


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 9.444444444444438, 'Empathy')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df3, x="empathy", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Empathy", fontsize=17)
plt.ylabel("Density", fontsize=13)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_empathy.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df3, x="empathy", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Empathy", fontsize=17)
plt.ylabel("Density", fontsize=13)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_empathy_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df3, x="empathy", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("", fontsize=13)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_empathy_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
ks= stats.ks_2samp(df3[df3["party_2"] =="D"].empathy, df3[df3["party_2"] =="R"].empathy)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.29165017807677085, pvalue=8.799946939432621e-71, statistic_location=0.5, statistic_sign=-1)
# True

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df3, x="sympathy", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Sympathy of 116th House One-Minute Speeches by Party")
plt.xlabel("Sympathy")


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 9.444444444444438, 'Sympathy')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df3, x="sympathy", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Sympathy", fontsize=17)
plt.ylabel("Density", fontsize=13)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_sympathy.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df3, x="sympathy", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("Sympathy", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 1.9)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_sympathy_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df3, x="sympathy", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 117th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("", fontsize=13)
plt.ylim(0, 1.9)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/116_sympathy_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
ks= stats.ks_2samp(df3[df3["party_2"] =="D"].sympathy, df3[df3["party_2"] =="R"].sympathy)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.24920295833249492, pvalue=1.336861800044766e-51, statistic_location=0.7, statistic_sign=-1)
# True

# %%
###### ks-testing 

ks= stats.ks_2samp(df[df["party_2"] =="D"].valence, df[df["party_2"] =="R"].valence)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.12383545840515651, pvalue=5.514528365576761e-13, statistic_location=0.56, statistic_sign=1)
# True

# %%
ks= stats.ks_2samp(df2[df2["party_2"] =="D"].arousal, df2[df2["party_2"] =="R"].arousal)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.16231591467518036, pvalue=5.048411283319375e-22, statistic_location=0.57, statistic_sign=-1)
# True

# %%
ks= stats.ks_2samp(df2[df2["party_2"] =="D"].confidence, df2[df2["party_2"] =="R"].confidence)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.03893039914684123, pvalue=0.11286592676353029, statistic_location=0.6, statistic_sign=-1)
# False

# %%
ks= stats.ks_2samp(df3[df3["party_2"] =="D"].sympathy, df3[df3["party_2"] =="R"].sympathy)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.24920295833249492, pvalue=1.336861800044766e-51, statistic_location=0.7, statistic_sign=-1)
# True

# %%
ks= stats.ks_2samp(df3[df3["party_2"] =="D"].empathy, df3[df3["party_2"] =="R"].empathy)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.29165017807677085, pvalue=8.799946939432621e-71, statistic_location=0.5, statistic_sign=-1)
# True
