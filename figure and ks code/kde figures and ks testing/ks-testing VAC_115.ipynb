# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

import numpy as np

# %%
df= pd.read_csv("/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/speeches_VAC_115th/speeches_VACES_115.csv")

# %%
def get_party(data):
    return(data[0])
df["party"] = df["party_state"].str.split("-").apply(get_party)

# %%
df["party_2"]= np.where(df["party"] == "R", "R", "D")

# %%
print(sum(df["party_2"] =="D")) #1269 D 
print(sum(df["party_2"] =="R")) #1363 R
print(len(df)) #2632
print(sum(df["party_2"] =="R")/len(df))
# Out:
# 1269
# 1363
# 2632
# 0.5178571428571429

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="valence", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Valence", fontsize=17)
plt.ylabel("Density", fontsize=13)
#plt.ylim(0, .75)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_valence.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="valence", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Valence", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, .75)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_valence_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="valence", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, .75)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_valence_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
ks= stats.ks_2samp(df[df["party_2"] =="D"].valence, df[df["party_2"] =="R"].valence)
ks
# Out:
# KstestResult(statistic=0.28618787532947476, pvalue=6.280947775191645e-48, statistic_location=-0.1, statistic_sign=1)

# %%
ks.pvalue <.05
# Out:
# True

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="arousal", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Arousal of 115th House One-Minute Speeches by Party")
plt.xlabel("Arousal")


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# (0.0, 1.6)

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="arousal", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Arousal", fontsize=17)
plt.ylabel("Density", fontsize=13)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_arousal.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="arousal", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Arousal", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 1.6)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_arousal_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="arousal", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 1.6)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_arousal_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
ks= stats.ks_2samp(df[df["party_2"] =="D"].arousal, df[df["party_2"] =="R"].arousal)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.1351593706692753, pvalue=6.225436554248531e-11, statistic_location=0.53, statistic_sign=-1)
# True

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="confidence", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Confidence of 115th House One-Minute Speeches by Party")
plt.xlabel("Confidence")


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 9.444444444444438, 'Confidence')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="confidence", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Confidence", fontsize=17)
plt.ylabel("Density", fontsize=13)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_confidence.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="confidence", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Confidence", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 2.7)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_confidence_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="confidence", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 2.7)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_confidence_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
ks= stats.ks_2samp(df[df["party_2"] =="D"].confidence, df[df["party_2"] =="R"].confidence)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.22958615255020243, pvalue=7.374170594301198e-31, statistic_location=0.45, statistic_sign=1)
# True

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="empathy", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Empathy of 115th House One-Minute Speeches by Party")
plt.xlabel("Empathy", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 1.3)

#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# (0.0, 1.3)

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="empathy", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Empathy", fontsize=17)
plt.ylabel("Density", fontsize=13)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_empathy.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="empathy", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Empathy", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 1.2)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_empathy_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="empathy", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 1.2)


plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_empathy_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
ks= stats.ks_2samp(df[df["party_2"] =="D"].empathy, df[df["party_2"] =="R"].empathy)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.14901768973669194, pvalue=3.3606376862003166e-13, statistic_location=0.4, statistic_sign=-1)
# True

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="sympathy", hue="party_2", kind="kde", palette =palette, legend= False)
plt.legend(labels= ['Republican', 'Democrat'])
plt.title("Sypmathy of 115th House One-Minute Speeches by Party")
plt.xlabel("Sympathy")


#plt.savefig('117thHousekde.png', dpi=300, bbox_inches='tight')
# Out:
# (0.0, 1.9)

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="sympathy", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Sympathy", fontsize=17)
plt.ylabel("Density", fontsize=13)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_sympathy.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="sympathy", hue="party_2", kind="kde", palette =palette, legend= False)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("Sympathy", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 1.9)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_sympathy_scaled.png', dpi=500, bbox_inches='tight')

# %%
palette ={"R": "Red", "D": "Blue"}

sns.displot(data=df, x="sympathy", hue="party_2", kind="kde", palette =palette, legend= False, linewidth = 2)
#plt.legend(labels= ['Republican', 'Democrat'])
#plt.title("Valence of 115th House One-Minute Speeches by Party")
plt.xlabel("", fontsize=17)
plt.ylabel("Density", fontsize=13)
plt.ylim(0, 1.9)

plt.savefig('/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/figures/115_sympathy_scaled_0.png', dpi=500, bbox_inches='tight')

# %%
ks= stats.ks_2samp(df[df["party_2"] =="D"].sympathy, df[df["party_2"] =="R"].sympathy)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.15401755387081872, pvalue=4.5006679676914683e-14, statistic_location=0.7, statistic_sign=-1)
# True

# %%
###### ks-testing 

ks= stats.ks_2samp(df[df["party_2"] =="D"].valence, df[df["party_2"] =="R"].valence)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.28618787532947476, pvalue=6.280947775191645e-48, statistic_location=-0.1, statistic_sign=1)
# True

# %%
ks= stats.ks_2samp(df[df["party_2"] =="D"].arousal, df[df["party_2"] =="R"].arousal)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.1351593706692753, pvalue=6.225436554248531e-11, statistic_location=0.53, statistic_sign=-1)
# True

# %%
ks= stats.ks_2samp(df[df["party_2"] =="D"].confidence, df[df["party_2"] =="R"].confidence)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.22958615255020243, pvalue=7.374170594301198e-31, statistic_location=0.45, statistic_sign=1)
# True

# %%
ks= stats.ks_2samp(df[df["party_2"] =="D"].sympathy, df[df["party_2"] =="R"].sympathy)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.15401755387081872, pvalue=4.5006679676914683e-14, statistic_location=0.7, statistic_sign=-1)
# True

# %%
ks= stats.ks_2samp(df[df["party_2"] =="D"].empathy, df[df["party_2"] =="R"].empathy)
print(ks)
print(ks.pvalue < .05)
# Out:
# KstestResult(statistic=0.14901768973669194, pvalue=3.3606376862003166e-13, statistic_location=0.4, statistic_sign=-1)
# True
