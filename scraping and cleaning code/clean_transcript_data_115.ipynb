# %%
# written on 11/15/23 by @caramnix 
import pandas as pd
import numpy as np
import math

# %%
df= pd.read_csv("/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/115th_transcript_data/115th_raw_date.csv", low_memory=False)

# %%
#df.dtypes

# %%
#["nan" if math.isnan(i) else i for i in df["text"]]

# %%
#get rid of weird empty columns
df= df[['url', 'time', 'name', 'party-state', 'text', 'congress', 'date']]

# %%
df.dtypes
# Out:
# url            object
# time           object
# name           object
# party-state    object
# text           object
# congress       object
# date           object
# dtype: object

# %%
# get rid of columsn w/ all NA valus (math,isnan()), sometheing weirdhappenend, impacts <100 rows 
df= df.dropna(how="all")

# %%
#math.isnan(df["text"])

# %%
def find_string(data):
    if type(data) is str: 
        data= data.lower()
        data = data.replace('-', ' ')      
        return ("one minute" in data)
    else: 
        return data

# %%
# find "one minute" in the text 
df["one_minute_bin"] = df["text"].apply(find_string)

# %%
df[13:40]
# Out:
#                                                   url     time  \
# 13  https://www.c-span.org/video/?420804-1&action=...  1:43:38
# 14  https://www.c-span.org/video/?420804-1&action=...  1:50:42
# 15  https://www.c-span.org/video/?420804-1&action=...  1:53:41
# 16  https://www.c-span.org/video/?420804-1&action=...  2:05:03
# 17  https://www.c-span.org/video/?420804-1&action=...  2:15:33
# 18  https://www.c-span.org/video/?420804-1&action=...  2:26:13
# 19  https://www.c-span.org/video/?420804-1&action=...  2:27:05
# 20  https://www.c-span.org/video/?420804-1&action=...  2:30:01
# 21  https://www.c-span.org/video/?420804-1&action=...  2:30:04
# 22  https://www.c-span.org/video/?420804-1&action=...  2:30:18
# 23  https://www.c-span.org/video/?420804-1&action=...  2:30:34
# 24  https://www.c-span.org/video/?420804-1&action=...  2:30:37
# 25  https://www.c-span.org/video/?420804-1&action=...  2:30:42
# 26  https://www.c-span.org/video/?420804-1&action=...  2:31:02
# 27  https://www.c-span.org/video/?420804-1&action=...  2:31:19
# 28  https://www.c-span.org/video/?420804-1&action=...  2:31:29
# 29  https://www.c-span.org/video/?420804-1&action=...  2:31:42
# 30  https://www.c-span.org/video/?420804-1&action=...  2:32:17
# 31  https://www.c-span.org/video/?420804-1&action=...  2:32:19
# 32  https://www.c-span.org/video/?420804-1&action=...  2:32:29
# 33  https://www.c-span.org/video/?420804-1&action=...  2:32:43
# 34  https://www.c-span.org/video/?420804-1&action=...  2:33:05
# 35  https://www.c-span.org/video/?420804-1&action=...  2:33:06
# 36  https://www.c-span.org/video/?420804-1&action=...  2:33:13
# 37  https://www.c-span.org/video/?420804-1&action=...  2:33:26
# 38  https://www.c-span.org/video/?420804-1&action=...  2:33:43
# 39  https://www.c-span.org/video/?420804-1&action=...  2:34:00
#
#                       name party-state  \
# 13                     NaN         NaN
# 14         Stacey Plaskett        D-VI
# 15                     NaN         NaN
# 16            Nancy Pelosi        D-CA
# 17            Paul D. Ryan        R-WI
# 18                     NaN         NaN
# 19                     NaN         NaN
# 20                     NaN         NaN
# 21                     NaN         NaN
# 22  Cathy McMorris Rodgers        R-WA
# 23                     NaN         NaN
# 24                     NaN         NaN
# 25                     NaN         NaN
# 26             Joe Crowley        D-NY
# 27                     NaN         NaN
# 28  Cathy McMorris Rodgers        R-WA
# 29             Joe Crowley        D-NY
# 30                     NaN         NaN
# 31                     NaN         NaN
# 32                     NaN         NaN
# 33                     NaN         NaN
# 34                     NaN         NaN
# 35  Cathy McMorris Rodgers        R-WA
# 36             Joe Crowley        D-NY
# 37                     NaN         NaN
# 38                     NaN         NaN
# 39                     NaN         NaN
#
#                                                  text congress      date  \
# 13  time. the clerk of the house: the  tellers agr...      115  3-Jan-17
# 14  stacey plaskett, d-viryan of the state of wisc...      115  3-Jan-17
# 15  madam clerk, the speaker-elect, paul d. ryan, ...      115  3-Jan-17
# 16  nancy pelosi, d-cato new members and your fami...      115  3-Jan-17
# 17  paul d. ryan, r-wiyou. thank you. thank you ve...      115  3-Jan-17
# 18  do. mr. conyers: thank you. i now pronounce yo...      115  3-Jan-17
# 19                                            2:27:05      115  3-Jan-17
# 20                                            floor.       115  3-Jan-17
# 21  the chair recognizes the gentlewoman from wash...      115  3-Jan-17
# 22  cathy mcmorris rodgers, r-wamccarthy. the spea...      115  3-Jan-17
# 23                        the house is not in order.       115  3-Jan-17
# 24  members and members' families  please take in ...      115  3-Jan-17
# 25  the gentleman deserves to be heard. the house ...      115  3-Jan-17
# 26  joe crowley, d-nypelosi.  the speaker: the cha...      115  3-Jan-17
# 27  miss mcmcmorris: i notify the house officially...      115  3-Jan-17
# 28  cathy mcmorris rodgers, r-wascalise. the speak...      115  3-Jan-17
# 29  joe crowley, d-nyclyburn. the speaker: recogni...      115  3-Jan-17
# 30                                      that paul b.       115  3-Jan-17
# 31  irving --  the speaker: the house is not  in o...      115  3-Jan-17
# 32  resolution. the clerk may proceed. the clerk: ...      115  3-Jan-17
# 33  the speaker: the gentlewoman from washington i...      115  3-Jan-17
# 34                 crowley: i thank the  gentlelady.       115  3-Jan-17
# 35  cathy mcmorris rodgers, r-wamr. speaker, i hav...      115  3-Jan-17
# 36  joe crowley, d-nyso many as are in favor say a...      115  3-Jan-17
# 37  and the portion of the resolution is agreed to...      115  3-Jan-17
# 38  order. the gentleman from new york, mr. crowle...      115  3-Jan-17
# 39  crowley of new york for the remainder of house...      115  3-Jan-17
#
#     one_minute_bin
# 13           False
# 14           False
# 15           False
# 16           False
# 17           False
# 18           False
# 19           False
# 20           False
# 21           False
# 22           False
# 23           False
# 24           False
# 25           False
# 26           False
# 27           False
# 28           False
# 29           False
# 30           False
# 31           False
# 32           False
# 33           False
# 34           False
# 35           False
# 36           False
# 37           False
# 38           False
# 39           False

# %%
df.iloc[14].text
# Out:
# 'stacey plaskett, d-viryan of the state of wisconsin has received 239. the honorable nancy pelosi of the state of california has received 189. the honorable tim ryan of the state of ohio has received two. the honorable jim cooper of the state of tennessee has received one. the honorable john lewis of the state of georgia has received one. the honorable daniel webster of the state of florida has received one. therefore, the honorable paul d. ryan of the state of wisconsin, having received a majority of the votes cast, is duly elected speaker of the house of representatives to the 115th congress. the clerk appoints the following committee to escort the speaker-elect to the chair. the gentleman from california, mr. mccarthy, the gentlewoman from california, ms. pelosi, the gentleman from louisiana, mr. scalise, the gentleman from maryland, mr. hoyer, the gentlewoman from washington, mrs. mcmorris rodgers, the gentleman from south carolina, mr. clyburn, the gentleman from ohio, mr. stivers, the gentleman from new york, mr. crowley, the gentleman from indiana, mr. messer, the gentlewoman from california, ms. sanchez, the gentleman from georgia, mr. collins, the gentleman from new mexico, mr. ben ray lujan, the gentleman from missouri, mr. smith, the gentlewoman from connecticut, ms. delauro, the gentlewoman from california, mrs. mimi walter, the gentleman from california, mr. swalwell, the gentleman from michigan, mr. mitchell, the gentleman from michigan, mr. levin, the gentleman from texas, mr. sessions, the gentlewoman from new york, mrs. lowey, the gentleman from north carolina, mr. mchenry, and the members of the wisconsin delegation, mr. sensenbrenner, mr. kind, ms. moore, mr. duffy, mr. pocan, mr. grothman, mr. gallagher. the committee will retire from the chamber to escort the speaker-little bit to the chair -- the speaker-elect to the chair. >> ... show full text show less text'

# %%
one_minute_df = df[df["one_minute_bin"] ==True]

# %%
one_minute_df['index_col']= one_minute_df.index
# Out:
# /var/folders/09/l3m63nj90fg1l2jshjp_hd5w0000gn/T/ipykernel_90762/376822450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   one_minute_df['index_col']= one_minute_df.index

# %%
one_minute_df.head()
# Out:
#                                                   url     time           name  \
# 86  https://www.c-span.org/video/?420804-1&action=...  3:30:37    Steny Hoyer
# 87  https://www.c-span.org/video/?420804-1&action=...  3:36:15            NaN
# 90  https://www.c-span.org/video/?420804-1&action=...  3:37:45            NaN
# 92  https://www.c-span.org/video/?420804-1&action=...  3:37:58   Rosa DeLauro
# 94  https://www.c-span.org/video/?420804-1&action=...  3:39:44  Eric Swalwell
#
#    party-state                                               text congress  \
# 86        D-MD  steny hoyer, d-mdfirst, reinstating the rule w...      115
# 87         NaN  the gentlelady from new york. ms. slaughter: m...      115
# 90         NaN  the speaker pro tempore: the  gentlewoman from...      115
# 92        D-CT  rosa delauro, d-ctmust. discretionary programs...      115
# 94        D-CA  eric swalwell, d-catoday also marks a united e...      115
#
#         date  one_minute_bin  index_col
# 86  3-Jan-17            True         86
# 87  3-Jan-17            True         87
# 90  3-Jan-17            True         90
# 92  3-Jan-17            True         92
# 94  3-Jan-17            True         94

# %%
#one_minute_df["text"][86]

# %%
#one_minute_df.loc[37345]['text']
#one_minute_df.loc[37351]['text']

# %%
# mentions one minute, then the NEXT one is the one-minute speech 

# mentions one minute, then the next statement is "without objection, the gentlewoman is recogni..." and it's the NEXT one with the speech 

# idea: everytime one-minute mentioned, take next 5 lines.
# if the next line has "without objection", go to the next line! 
# then if the next line has a named speaker, this is the one minute speech-
# record "start time" / time stamp 
# also check to see if the next (2) lines have same speaker,
# lump them all into one  if so, since these are the same speech. 
# also take time stamp from *next* line after speech done, add as row "end time"

# %%
# preininitalize columns of df 
#colnames= ["url", "start_time", "end_time", "name", "party_state", "text", 'congress', "date"]
#new_df = pd.DataFrame(columns = colnames)

# %%
#for i in range(0, len(one_minute_df)): 
#    index= int(one_minute_df.iloc[i].index_col)
#    
#    if pd.isna(df.iloc[index+1]["party-state"]) == False: #if name of next line is not NA... 
#        url = df.iloc[index+1].url 
#        start_time =  df.iloc[index+1].time
#        name = df.iloc[index+1]["name"]  
#        party_state =  df.iloc[index+1]["party-state"]
#        congress = 116 
#        date= df.iloc[index+1].date
        
        #this should be 1 min speech
#        if df.iloc[index+1]["name"] == df.iloc[index+2]["name"]: #if name matches for next two, combine 
#            text_of_speech= df.iloc[index+1].text + df.iloc[index+2].text
#            end_time = df.iloc[index+3].time 
#
#        else: 
#            text_of_speech= df.iloc[index+1].text
#            end_time = df.iloc[index+2].time
#    
#    
#        list_i = [url, start_time, end_time, name, party_state,text_of_speech, congress, date]
#        new_df.loc[len(new_df)] = list_i
#    else: #if name is na 
#       pass

# %%
# preininitalize columns of df 
colnames= ["url", "start_time", "end_time", "name", "party_state", "text", 'congress', "date"]
new_df = pd.DataFrame(columns = colnames)

# %%
ct=0 
forgotten_indicies= []
for i in range(0, len(one_minute_df)): 
    index= int(one_minute_df.iloc[i].index_col)
    if pd.isna(df.iloc[index+1]["name"]) == False: #if name of next line is not NA... 
        url = df.iloc[index+1].url 
        start_time =  df.iloc[index+1].time
        name = df.iloc[index+1]["name"]  
        party_state =  df.iloc[index+1]["party-state"]
        congress = 115 
        date= df.iloc[index+1].date
        
        #this should be 1 min speech
        if df.iloc[index+1]["name"] == df.iloc[index+2]["name"]: #if name matches for next two, combine 
            text_of_speech= df.iloc[index+1].text + df.iloc[index+2].text
            end_time = df.iloc[index+3].time 
            ct+=1

        else: 
            text_of_speech= df.iloc[index+1].text
            end_time = df.iloc[index+2].time
    
    
        list_i = [url, start_time, end_time, name, party_state,text_of_speech, congress, date]
        new_df.loc[len(new_df)] = list_i
    else: #if name of next is na 
        
        # if it says is recognized and doesn't say false, i.e. won't be caught otherwise 
        if ("is recognized" in df.iloc[index+1].text) and (df.iloc[index+1].one_minute_bin == False): 
            
            #if the name isn't NA for the next one 
            if pd.isna(df.iloc[index+2]["name"]) == False:
                url = df.iloc[index+2].url 
                start_time =  df.iloc[index+2].time
                name = df.iloc[index+2]["name"]  
                party_state =  df.iloc[index+2]["party-state"]
                congress = 115
                date= df.iloc[index+2].date
                
                #this should be 1 min speech
                if df.iloc[index+2]["name"] == df.iloc[index+3]["name"]: #if name matches for next two, combine 
                    text_of_speech= df.iloc[index+2].text + df.iloc[index+3].text
                    end_time = df.iloc[index+4].time 
                    ct+=1
                else: 
                    text_of_speech= df.iloc[index+2].text
                    end_time = df.iloc[index+3].time
            list_i = [url, start_time, end_time, name, party_state,text_of_speech, congress, date]
            new_df.loc[len(new_df)] = list_i
            
        else: 
            #also appends ones who get caught the next go around, i.e. because one_minute_bin is True 
            forgotten_indicies.append(i)
                
            
    
    #mini_df= df.iloc[index: index+5]

# %%
ct # 334 times we combined  --> thinking we might need to look at this text more carefully for finding when to combine@
# Out:
# 334

# %%
#forgotten_indicies[0:5]

# %%
#one_minute_df.iloc[5]

# %%
#df[one_minute_df.iloc[5].index_col: one_minute_df.iloc[5].index_col+5]

# %%
new_df
# Out:
#                                                     url start_time end_time  \
# 0     https://www.c-span.org/video/?420804-1&action=...    3:39:32  3:39:44
# 1     https://www.c-span.org/video/?420804-1&action=...    3:40:48  3:41:00
# 2     https://www.c-span.org/video/?420804-1&action=...    4:09:15  4:23:10
# 3     https://www.c-span.org/video/?420995-101&actio...    0:02:23  0:03:37
# 4     https://www.c-span.org/video/?420995-101&actio...    0:06:44  0:07:53
# ...                                                 ...        ...      ...
# 2972  https://www.c-span.org/video/?456223-1&action=...    0:02:51  0:03:48
# 2973  https://www.c-span.org/video/?456223-1&action=...    0:06:32  0:06:49
# 2974  https://www.c-span.org/video/?456223-1&action=...    0:06:32  0:06:49
# 2975  https://www.c-span.org/video/?456223-1&action=...    0:06:59  0:08:06
# 2976  https://www.c-span.org/video/?456223-1&action=...    0:06:59  0:08:06
#
#                        name party_state  \
# 0          Louise Slaughter        D-NY
# 1          Louise Slaughter        D-NY
# 2              Nancy Pelosi        D-CA
# 3              Buddy Carter        R-GA
# 4              Cheri Bustos        D-IL
# ...                     ...         ...
# 2972  John James Duncan Jr.        R-TN
# 2973             Brian Mast        R-FL
# 2974             Brian Mast        R-FL
# 2975             Dina Titus        D-NV
# 2976             Dina Titus        D-NV
#
#                                                    text  congress       date
# 0     louise slaughter, d-nymr. swalwell: today star...       115   3-Jan-17
# 1     louise slaughter, d-nymeans, mr. neal. mr. nea...       115   3-Jan-17
# 2     nancy pelosi, d-cait is an honor to serve in t...       115   3-Jan-17
# 3     buddy carter, r-gajimmy burnson who has served...       115   4-Jan-17
# 4     cheri bustos, d-ilbustos: by remoping the medi...       115   4-Jan-17
# ...                                                 ...       ...        ...
# 2972  john james duncan jr., r-tntoo many of our lea...       115  21-Dec-18
# 2973  brian mast, r-flh.res. 1063 designates the roo...       115  21-Dec-18
# 2974  brian mast, r-flh.res. 1063 designates the roo...       115  21-Dec-18
# 2975  dina titus, d-nvthank you. i also support hous...       115  21-Dec-18
# 2976  dina titus, d-nvthank you. i also support hous...       115  21-Dec-18
#
# [2977 rows x 8 columns]

# %%
def remove_name_from_text(row):    
    name_party= row['name'].lower() + ", " + row["party_state"].lower() 
    without_name= row['text'].replace(name_party, " ")
    return(without_name.replace("show full text show less text", " "))

# %%
new_df.iloc[2856]
# Out:
# url            https://www.c-span.org/video/?451991-2&action=...
# start_time                                               0:00:10
# end_time                                                 0:01:14
# name                                           Patrick J. Conroy
# party_state                                                  NaN
# text           patrick j. conroylet us pray. merciful god we ...
# congress                                                     115
# date                                                   27-Sep-18
# Name: 2856, dtype: object

# %%
cleaned_text=[]
for i in range(0,len(new_df)): 
    try: 
        cleaned_text.append(remove_name_from_text(new_df.iloc[i]))
    except AttributeError: 
        cleaned_text.append(new_df.iloc[i].text)

# %%
new_df['cleaned_text']= cleaned_text

# %%
new_df
# Out:
#                                                     url start_time end_time  \
# 0     https://www.c-span.org/video/?420804-1&action=...    3:39:32  3:39:44
# 1     https://www.c-span.org/video/?420804-1&action=...    3:40:48  3:41:00
# 2     https://www.c-span.org/video/?420804-1&action=...    4:09:15  4:23:10
# 3     https://www.c-span.org/video/?420995-101&actio...    0:02:23  0:03:37
# 4     https://www.c-span.org/video/?420995-101&actio...    0:06:44  0:07:53
# ...                                                 ...        ...      ...
# 2972  https://www.c-span.org/video/?456223-1&action=...    0:02:51  0:03:48
# 2973  https://www.c-span.org/video/?456223-1&action=...    0:06:32  0:06:49
# 2974  https://www.c-span.org/video/?456223-1&action=...    0:06:32  0:06:49
# 2975  https://www.c-span.org/video/?456223-1&action=...    0:06:59  0:08:06
# 2976  https://www.c-span.org/video/?456223-1&action=...    0:06:59  0:08:06
#
#                        name party_state  \
# 0          Louise Slaughter        D-NY
# 1          Louise Slaughter        D-NY
# 2              Nancy Pelosi        D-CA
# 3              Buddy Carter        R-GA
# 4              Cheri Bustos        D-IL
# ...                     ...         ...
# 2972  John James Duncan Jr.        R-TN
# 2973             Brian Mast        R-FL
# 2974             Brian Mast        R-FL
# 2975             Dina Titus        D-NV
# 2976             Dina Titus        D-NV
#
#                                                    text  congress       date  \
# 0     louise slaughter, d-nymr. swalwell: today star...       115   3-Jan-17
# 1     louise slaughter, d-nymeans, mr. neal. mr. nea...       115   3-Jan-17
# 2     nancy pelosi, d-cait is an honor to serve in t...       115   3-Jan-17
# 3     buddy carter, r-gajimmy burnson who has served...       115   4-Jan-17
# 4     cheri bustos, d-ilbustos: by remoping the medi...       115   4-Jan-17
# ...                                                 ...       ...        ...
# 2972  john james duncan jr., r-tntoo many of our lea...       115  21-Dec-18
# 2973  brian mast, r-flh.res. 1063 designates the roo...       115  21-Dec-18
# 2974  brian mast, r-flh.res. 1063 designates the roo...       115  21-Dec-18
# 2975  dina titus, d-nvthank you. i also support hous...       115  21-Dec-18
# 2976  dina titus, d-nvthank you. i also support hous...       115  21-Dec-18
#
#                                            cleaned_text
# 0      mr. swalwell: today starts the  efforts to en...
# 1      means, mr. neal. mr. neal: just the facts, ma...
# 2      it is an honor to serve in this house. we hav...
# 3      jimmy burnson who has served as chairman of t...
# 4      bustos: by remoping the medicare doughnut hol...
# ...                                                 ...
# 2972   too many of our leaders seem to want to be mo...
# 2973   h.res. 1063 designates the room h-226 of the ...
# 2974   h.res. 1063 designates the room h-226 of the ...
# 2975   thank you. i also support house resolution 10...
# 2976   thank you. i also support house resolution 10...
#
# [2977 rows x 9 columns]

# %%
new_df.to_csv("/Users/caranix/Library/CloudStorage/OneDrive-TheOhioStateUniversity/CS MS/CSPAN/115th_transcript_data/cleaned_transcript_data_115th.csv")
